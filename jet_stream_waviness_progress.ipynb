# %% [markdown]
# # Modeling Jet Stream Waviness
# ### Alyssa Dellinger, Elliana Hebert, Katie-Rose Slade

# %% [markdown]
# ## Introduction

# %% [markdown]
# The scientific theory and model of jet stream waviness plays a pivotal role in our understanding of atmospheric dynamics and climate patterns. The jet stream, a high-altitude, fast-flowing air current, is a key component of the Earth's atmospheric circulation. In recent years, researchers have been increasingly intrigued by the phenomenon of jet stream waviness, characterized by meandering patterns that deviate from the traditional straight and zonal flow. This waviness has been linked to a range of atmospheric and climatic phenomena, including extreme weather events, prolonged periods of heat or cold, and disruptions to regional weather patterns.
#
# Understanding the factors influencing jet stream waviness is crucial for predicting and mitigating the impacts of climate change on a global scale. Scientists employ sophisticated models and theories to investigate the intricate interactions between atmospheric components, such as temperature gradients, pressure systems, and the Coriolis effect, which contribute to the development of jet stream waviness. This research not only enhances our ability to forecast weather patterns but also provides valuable insights into the broader implications of a changing climate on ecosystems, agriculture, and human societies.

# %% [markdown]
# ## Equations

# %% [markdown]
# The principle equation we are to solve is the Linearized Planetary Geostrophic Motion model. This model is used to describe the large-scale motion of the atmosphere under the influence of the Earth's rotation. Ine the The equation is as follows:

# %% [markdown]
# $$\frac{\partial^2 \phi_{L}}{\partial z} - \frac{1}{H} \frac{\partial\phi_{L}}{\partial z} + \frac{\beta_{L}S}{U} \phi_{L}  = - \Biggl ({k_{S} +\frac{1}{H} \Biggl)}  \frac{Q_{0}}{U} F(x) e^{-k_{s}z}$$

# %% [markdown]
# The boundary conditions for the model are as follows:

# %% [markdown]
# $$ U \frac{\partial}{\partial x} \frac{\partial \phi_{L}}{\partial z} + Sw_{L}  = Q_{0} G(x)  e^{-k_{s}z}$$

# %% [markdown]
# $$ \Biggl ( \frac{\partial}{\partial z} - \frac{1}{H}\Biggl ) w_{L}  + Sw_{L}  = \beta_{L} \frac{\partial \phi_{L}}{\partial x}$$

# %% [markdown]
# Add more about what these equations mean...

# %% [markdown]
# ## Numerical methods

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import spdiags
import math

# %% [markdown]
# #### Define Variables

# %%
#define parameters

k_s = 2
beta = 1
H = 0.5
S = 1
U = 1.5

q0 = 1 #??

def f(x):
    return np.sin(2*x)/2

def g(x):
    return np.cos(2*x)

#q = np.sqrt((1/(4*H**2))-((beta*S)/U))

# %% [markdown]
# ## Results

# %%
#grid 

#alpha = 1
#
#xf = 1000
#zf = 1
#
#nx = 1000
#nz = 1000
#
#x = np.linspace(0,xf,nx)
#z = np.linspace(0,zf,nz)
#
#dx = x[1]-x[0]
#dz = z[1]-z[0]
#
##constant wavelength
#lam = np.ones(nw_L)
#lam = lam * (alpha*(dz)/dw_L)


#x(og)=z
#t(og)=x
D = 1 #diffusion constant, idk value
Cd= 0.1

xf = 1000
zf = 1000

nx = 1000
nz = 1000

x = np.linspace(0,xf,nx)
z = np.linspace(0,zf,nz)

dz = z[1]-z[0]
dx = (dz**2)*Cd/D

# %%
#prop matrix
#M is matrix of phi 

data = np.array([Cd*np.ones(nz), (1-2*Cd)*np.ones(nz), Cd*np.ones(nz)])
diags = np.array([-1, 0, 1])
M = spdiags(data, diags, nz, nz).toarray()

# %%
#Preallocate vectors

soln = np.zeros([nz,nx+1]) #solution matrix
soln_init = np.zeros([nz,1]) #initial conditions

# %%
#boundary conditions

M[0,0] = (q0*U)*f(x[0]) 
M[-1,-1] = (q0/U)*f(x[-1])*np.exp(-1*k_s)

# %%
#model

for k in range(0,nx):
    for i in range(0,nz):
        soln[i,k+1] = (dz**2)/(1+(dz/H))*((k+(1/H))*(q0/U)*f(x[k])*np.exp(-1*k_s*z[i])-(1/H)*(soln[i,k]/dz)
                                          +((beta*S)/U)*soln[i,k]+2*soln[i,k]-soln[i-1,k])
    soln_new = np.matmul(M,soln[:,k])
    soln[:,k+1] = soln_new.transpose()

# %%
plt.plot(z,soln)
# Out:
# [<matplotlib.lines.Line2D at 0x259a171aac0>,
#  <matplotlib.lines.Line2D at 0x259a171ab80>,
#  <matplotlib.lines.Line2D at 0x259a171aca0>,
#  <matplotlib.lines.Line2D at 0x259a171adc0>,
#  <matplotlib.lines.Line2D at 0x259a171aee0>,
#  <matplotlib.lines.Line2D at 0x259a1724040>,
#  <matplotlib.lines.Line2D at 0x259a1724160>,
#  <matplotlib.lines.Line2D at 0x259a1724280>,
#  <matplotlib.lines.Line2D at 0x259a17243a0>,
#  <matplotlib.lines.Line2D at 0x259a17244c0>,
#  <matplotlib.lines.Line2D at 0x259a171ab50>,
#  <matplotlib.lines.Line2D at 0x259a17245e0>,
#  <matplotlib.lines.Line2D at 0x259a17247f0>,
#  <matplotlib.lines.Line2D at 0x259a1724910>,
#  <matplotlib.lines.Line2D at 0x259a1724a30>,
#  <matplotlib.lines.Line2D at 0x259a1724b50>,
#  <matplotlib.lines.Line2D at 0x259a1724c70>,
#  <matplotlib.lines.Line2D at 0x259a1724d90>,
#  <matplotlib.lines.Line2D at 0x259a1724eb0>,
#  <matplotlib.lines.Line2D at 0x259a1724fd0>,
#  <matplotlib.lines.Line2D at 0x259a172b130>,
#  <matplotlib.lines.Line2D at 0x259a172b250>,
#  <matplotlib.lines.Line2D at 0x259a172b370>,
#  <matplotlib.lines.Line2D at 0x259a172b490>,
#  <matplotlib.lines.Line2D at 0x259a172b5b0>,
#  <matplotlib.lines.Line2D at 0x259a172b6d0>,
#  <matplotlib.lines.Line2D at 0x259a172b7f0>,
#  <matplotlib.lines.Line2D at 0x259a172b910>,
#  <matplotlib.lines.Line2D at 0x259a172ba30>,
#  <matplotlib.lines.Line2D at 0x259a172bb50>,
#  <matplotlib.lines.Line2D at 0x259a172bc70>,
#  <matplotlib.lines.Line2D at 0x259a172bd90>,
#  <matplotlib.lines.Line2D at 0x259a172beb0>,
#  <matplotlib.lines.Line2D at 0x259a172bfd0>,
#  <matplotlib.lines.Line2D at 0x259a1731130>,
#  <matplotlib.lines.Line2D at 0x259a1731250>,
#  <matplotlib.lines.Line2D at 0x259a1731370>,
#  <matplotlib.lines.Line2D at 0x259a1731490>,
#  <matplotlib.lines.Line2D at 0x259a17315b0>,
#  <matplotlib.lines.Line2D at 0x259a17316d0>,
#  <matplotlib.lines.Line2D at 0x259a17317f0>,
#  <matplotlib.lines.Line2D at 0x259a1731910>,
#  <matplotlib.lines.Line2D at 0x259a1731a30>,
#  <matplotlib.lines.Line2D at 0x259a1731b50>,
#  <matplotlib.lines.Line2D at 0x259a1731c70>,
#  <matplotlib.lines.Line2D at 0x259a1731d90>,
#  <matplotlib.lines.Line2D at 0x259a1731eb0>,
#  <matplotlib.lines.Line2D at 0x259a1731fd0>,
#  <matplotlib.lines.Line2D at 0x259a1737130>,
#  <matplotlib.lines.Line2D at 0x259a1737250>,
#  <matplotlib.lines.Line2D at 0x259a1737370>,
#  <matplotlib.lines.Line2D at 0x259a1737490>,
#  <matplotlib.lines.Line2D at 0x259a17375b0>,
#  <matplotlib.lines.Line2D at 0x259a17376d0>,
#  <matplotlib.lines.Line2D at 0x259a17377f0>,
#  <matplotlib.lines.Line2D at 0x259a1737910>,
#  <matplotlib.lines.Line2D at 0x259a1737a30>,
#  <matplotlib.lines.Line2D at 0x259a1737b50>,
#  <matplotlib.lines.Line2D at 0x259a1737c70>,
#  <matplotlib.lines.Line2D at 0x259a1737d90>,
#  <matplotlib.lines.Line2D at 0x259a1737eb0>,
#  <matplotlib.lines.Line2D at 0x259a1737fd0>,
#  <matplotlib.lines.Line2D at 0x259a173f130>,
#  <matplotlib.lines.Line2D at 0x259a173f250>,
#  <matplotlib.lines.Line2D at 0x259a173f370>,
#  <matplotlib.lines.Line2D at 0x259a173f490>,
#  <matplotlib.lines.Line2D at 0x259a173f5b0>,
#  <matplotlib.lines.Line2D at 0x259a173f6d0>,
#  <matplotlib.lines.Line2D at 0x259a173f7f0>,
#  <matplotlib.lines.Line2D at 0x259a173f910>,
#  <matplotlib.lines.Line2D at 0x259a173fa30>,
#  <matplotlib.lines.Line2D at 0x259a173fb50>,
#  <matplotlib.lines.Line2D at 0x259a173fc70>,
#  <matplotlib.lines.Line2D at 0x259a173fd90>,
#  <matplotlib.lines.Line2D at 0x259a173feb0>,
#  <matplotlib.lines.Line2D at 0x259a173ffd0>,
#  <matplotlib.lines.Line2D at 0x259a1d24130>,
#  <matplotlib.lines.Line2D at 0x259a1d24250>,
#  <matplotlib.lines.Line2D at 0x259a1d24370>,
#  <matplotlib.lines.Line2D at 0x259a1d24490>,
#  <matplotlib.lines.Line2D at 0x259a1d245b0>,
#  <matplotlib.lines.Line2D at 0x259a1d246d0>,
#  <matplotlib.lines.Line2D at 0x259a1d247f0>,
#  <matplotlib.lines.Line2D at 0x259a1d24910>,
#  <matplotlib.lines.Line2D at 0x259a1d24a30>,
#  <matplotlib.lines.Line2D at 0x259a1d24b50>,
#  <matplotlib.lines.Line2D at 0x259a1d24c70>,
#  <matplotlib.lines.Line2D at 0x259a1d24d90>,
#  <matplotlib.lines.Line2D at 0x259a1d24eb0>,
#  <matplotlib.lines.Line2D at 0x259a1d24fd0>,
#  <matplotlib.lines.Line2D at 0x259a1d2b130>,
#  <matplotlib.lines.Line2D at 0x259a1d2b250>,
#  <matplotlib.lines.Line2D at 0x259a1d2b370>,
#  <matplotlib.lines.Line2D at 0x259a1d2b490>,
#  <matplotlib.lines.Line2D at 0x259a1d2b5b0>,
#  <matplotlib.lines.Line2D at 0x259a1d2b6d0>,
#  <matplotlib.lines.Line2D at 0x259a1d2b7f0>,
#  <matplotlib.lines.Line2D at 0x259a1d2b910>,
#  <matplotlib.lines.Line2D at 0x259a1d2ba30>,
#  <matplotlib.lines.Line2D at 0x259a1d2bb50>,
#  <matplotlib.lines.Line2D at 0x259a1d2bc70>,
#  <matplotlib.lines.Line2D at 0x259a1d2bd90>,
#  <matplotlib.lines.Line2D at 0x259a1d2beb0>,
#  <matplotlib.lines.Line2D at 0x259a1d2bfd0>,
#  <matplotlib.lines.Line2D at 0x259a1d31130>,
#  <matplotlib.lines.Line2D at 0x259a1d31250>,
#  <matplotlib.lines.Line2D at 0x259a1d31370>,
#  <matplotlib.lines.Line2D at 0x259a1d31490>,
#  <matplotlib.lines.Line2D at 0x259a1d315b0>,
#  <matplotlib.lines.Line2D at 0x259a1d316d0>,
#  <matplotlib.lines.Line2D at 0x259a1d317f0>,
#  <matplotlib.lines.Line2D at 0x259a1d31910>,
#  <matplotlib.lines.Line2D at 0x259a1d31a30>,
#  <matplotlib.lines.Line2D at 0x259a1d31b50>,
#  <matplotlib.lines.Line2D at 0x259a1d31c70>,
#  <matplotlib.lines.Line2D at 0x259a1d31d90>,
#  <matplotlib.lines.Line2D at 0x259a1d31eb0>,
#  <matplotlib.lines.Line2D at 0x259a1d31fd0>,
#  <matplotlib.lines.Line2D at 0x259a1d35130>,
#  <matplotlib.lines.Line2D at 0x259a1d35250>,
#  <matplotlib.lines.Line2D at 0x259a1d35370>,
#  <matplotlib.lines.Line2D at 0x259a1d35490>,
#  <matplotlib.lines.Line2D at 0x259a1d355b0>,
#  <matplotlib.lines.Line2D at 0x259a1d356d0>,
#  <matplotlib.lines.Line2D at 0x259a1d35820>,
#  <matplotlib.lines.Line2D at 0x259a1d35940>,
#  <matplotlib.lines.Line2D at 0x259a1d35a60>,
#  <matplotlib.lines.Line2D at 0x259a1d35b80>,
#  <matplotlib.lines.Line2D at 0x259a1d35ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d35dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d35ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d3c040>,
#  <matplotlib.lines.Line2D at 0x259a1d3c160>,
#  <matplotlib.lines.Line2D at 0x259a1d3c280>,
#  <matplotlib.lines.Line2D at 0x259a1d3c3a0>,
#  <matplotlib.lines.Line2D at 0x259a1d3c4c0>,
#  <matplotlib.lines.Line2D at 0x259a1d3c5e0>,
#  <matplotlib.lines.Line2D at 0x259a1d3c700>,
#  <matplotlib.lines.Line2D at 0x259a1d3c820>,
#  <matplotlib.lines.Line2D at 0x259a1d3c940>,
#  <matplotlib.lines.Line2D at 0x259a1d3ca60>,
#  <matplotlib.lines.Line2D at 0x259a1d3cb80>,
#  <matplotlib.lines.Line2D at 0x259a1d3cca0>,
#  <matplotlib.lines.Line2D at 0x259a1d3cdc0>,
#  <matplotlib.lines.Line2D at 0x259a1d3cee0>,
#  <matplotlib.lines.Line2D at 0x259a1d42040>,
#  <matplotlib.lines.Line2D at 0x259a1d42160>,
#  <matplotlib.lines.Line2D at 0x259a1d42280>,
#  <matplotlib.lines.Line2D at 0x259a1d423a0>,
#  <matplotlib.lines.Line2D at 0x259a1d424c0>,
#  <matplotlib.lines.Line2D at 0x259a1d425e0>,
#  <matplotlib.lines.Line2D at 0x259a1d42700>,
#  <matplotlib.lines.Line2D at 0x259a1d42820>,
#  <matplotlib.lines.Line2D at 0x259a1d42940>,
#  <matplotlib.lines.Line2D at 0x259a1d42a60>,
#  <matplotlib.lines.Line2D at 0x259a1d42b80>,
#  <matplotlib.lines.Line2D at 0x259a1d42ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d42dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d42ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d47040>,
#  <matplotlib.lines.Line2D at 0x259a1d47160>,
#  <matplotlib.lines.Line2D at 0x259a1d47280>,
#  <matplotlib.lines.Line2D at 0x259a1d473a0>,
#  <matplotlib.lines.Line2D at 0x259a1d474c0>,
#  <matplotlib.lines.Line2D at 0x259a1d475e0>,
#  <matplotlib.lines.Line2D at 0x259a1d47700>,
#  <matplotlib.lines.Line2D at 0x259a1d47820>,
#  <matplotlib.lines.Line2D at 0x259a1d47940>,
#  <matplotlib.lines.Line2D at 0x259a1d47a60>,
#  <matplotlib.lines.Line2D at 0x259a1d47b80>,
#  <matplotlib.lines.Line2D at 0x259a1d47ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d47dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d47ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d4d040>,
#  <matplotlib.lines.Line2D at 0x259a1d4d160>,
#  <matplotlib.lines.Line2D at 0x259a1d4d280>,
#  <matplotlib.lines.Line2D at 0x259a1d4d3a0>,
#  <matplotlib.lines.Line2D at 0x259a1d4d4c0>,
#  <matplotlib.lines.Line2D at 0x259a1d4d5e0>,
#  <matplotlib.lines.Line2D at 0x259a1d4d700>,
#  <matplotlib.lines.Line2D at 0x259a1d4d820>,
#  <matplotlib.lines.Line2D at 0x259a1d4d940>,
#  <matplotlib.lines.Line2D at 0x259a1d4da60>,
#  <matplotlib.lines.Line2D at 0x259a1d4db80>,
#  <matplotlib.lines.Line2D at 0x259a1d4dca0>,
#  <matplotlib.lines.Line2D at 0x259a1d4ddc0>,
#  <matplotlib.lines.Line2D at 0x259a1d4dee0>,
#  <matplotlib.lines.Line2D at 0x259a1d54040>,
#  <matplotlib.lines.Line2D at 0x259a1d54160>,
#  <matplotlib.lines.Line2D at 0x259a1d54280>,
#  <matplotlib.lines.Line2D at 0x259a1d543a0>,
#  <matplotlib.lines.Line2D at 0x259a1d544c0>,
#  <matplotlib.lines.Line2D at 0x259a1d545e0>,
#  <matplotlib.lines.Line2D at 0x259a1d54700>,
#  <matplotlib.lines.Line2D at 0x259a1d54820>,
#  <matplotlib.lines.Line2D at 0x259a1d54940>,
#  <matplotlib.lines.Line2D at 0x259a1d54a60>,
#  <matplotlib.lines.Line2D at 0x259a1d54b80>,
#  <matplotlib.lines.Line2D at 0x259a1d54ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d54dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d54ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d59040>,
#  <matplotlib.lines.Line2D at 0x259a1d59160>,
#  <matplotlib.lines.Line2D at 0x259a1d59280>,
#  <matplotlib.lines.Line2D at 0x259a1d593a0>,
#  <matplotlib.lines.Line2D at 0x259a1d594c0>,
#  <matplotlib.lines.Line2D at 0x259a1d595e0>,
#  <matplotlib.lines.Line2D at 0x259a1d59700>,
#  <matplotlib.lines.Line2D at 0x259a1d59820>,
#  <matplotlib.lines.Line2D at 0x259a1d59940>,
#  <matplotlib.lines.Line2D at 0x259a1d59a60>,
#  <matplotlib.lines.Line2D at 0x259a1d59b80>,
#  <matplotlib.lines.Line2D at 0x259a1d59ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d59dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d59ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d60040>,
#  <matplotlib.lines.Line2D at 0x259a1d60160>,
#  <matplotlib.lines.Line2D at 0x259a1d60280>,
#  <matplotlib.lines.Line2D at 0x259a1d603a0>,
#  <matplotlib.lines.Line2D at 0x259a1d604c0>,
#  <matplotlib.lines.Line2D at 0x259a1d605e0>,
#  <matplotlib.lines.Line2D at 0x259a1d60700>,
#  <matplotlib.lines.Line2D at 0x259a1d60820>,
#  <matplotlib.lines.Line2D at 0x259a1d60940>,
#  <matplotlib.lines.Line2D at 0x259a1d60a60>,
#  <matplotlib.lines.Line2D at 0x259a1d60b80>,
#  <matplotlib.lines.Line2D at 0x259a1d60ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d60dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d60ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d65040>,
#  <matplotlib.lines.Line2D at 0x259a1d65160>,
#  <matplotlib.lines.Line2D at 0x259a1d65280>,
#  <matplotlib.lines.Line2D at 0x259a1d653a0>,
#  <matplotlib.lines.Line2D at 0x259a1d654c0>,
#  <matplotlib.lines.Line2D at 0x259a1d655e0>,
#  <matplotlib.lines.Line2D at 0x259a1d65700>,
#  <matplotlib.lines.Line2D at 0x259a1d65820>,
#  <matplotlib.lines.Line2D at 0x259a1d65940>,
#  <matplotlib.lines.Line2D at 0x259a1d65a60>,
#  <matplotlib.lines.Line2D at 0x259a1d65b80>,
#  <matplotlib.lines.Line2D at 0x259a1d65ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d65dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d65ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d6a040>,
#  <matplotlib.lines.Line2D at 0x259a1d6a160>,
#  <matplotlib.lines.Line2D at 0x259a1d6a280>,
#  <matplotlib.lines.Line2D at 0x259a1d6a3a0>,
#  <matplotlib.lines.Line2D at 0x259a1d6a4c0>,
#  <matplotlib.lines.Line2D at 0x259a1d6a5e0>,
#  <matplotlib.lines.Line2D at 0x259a1d6a700>,
#  <matplotlib.lines.Line2D at 0x259a1d6a820>,
#  <matplotlib.lines.Line2D at 0x259a1d6a940>,
#  <matplotlib.lines.Line2D at 0x259a1d6aa60>,
#  <matplotlib.lines.Line2D at 0x259a1d6ab80>,
#  <matplotlib.lines.Line2D at 0x259a1d6aca0>,
#  <matplotlib.lines.Line2D at 0x259a1d6adc0>,
#  <matplotlib.lines.Line2D at 0x259a1d6aee0>,
#  <matplotlib.lines.Line2D at 0x259a1d71040>,
#  <matplotlib.lines.Line2D at 0x259a1d71160>,
#  <matplotlib.lines.Line2D at 0x259a1d71280>,
#  <matplotlib.lines.Line2D at 0x259a1d713a0>,
#  <matplotlib.lines.Line2D at 0x259a1d714c0>,
#  <matplotlib.lines.Line2D at 0x259a1d715e0>,
#  <matplotlib.lines.Line2D at 0x259a1d71700>,
#  <matplotlib.lines.Line2D at 0x259a1d71820>,
#  <matplotlib.lines.Line2D at 0x259a1d71940>,
#  <matplotlib.lines.Line2D at 0x259a1d71a60>,
#  <matplotlib.lines.Line2D at 0x259a1d71b80>,
#  <matplotlib.lines.Line2D at 0x259a1d71ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d71dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d71ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d77040>,
#  <matplotlib.lines.Line2D at 0x259a1d77160>,
#  <matplotlib.lines.Line2D at 0x259a1d77280>,
#  <matplotlib.lines.Line2D at 0x259a1d773a0>,
#  <matplotlib.lines.Line2D at 0x259a1d774c0>,
#  <matplotlib.lines.Line2D at 0x259a1d775e0>,
#  <matplotlib.lines.Line2D at 0x259a1d77700>,
#  <matplotlib.lines.Line2D at 0x259a1d77820>,
#  <matplotlib.lines.Line2D at 0x259a1d77940>,
#  <matplotlib.lines.Line2D at 0x259a1d77a60>,
#  <matplotlib.lines.Line2D at 0x259a1d77b80>,
#  <matplotlib.lines.Line2D at 0x259a1d77ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d77dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d77ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d7c040>,
#  <matplotlib.lines.Line2D at 0x259a1d7c160>,
#  <matplotlib.lines.Line2D at 0x259a1d7c280>,
#  <matplotlib.lines.Line2D at 0x259a1d7c3a0>,
#  <matplotlib.lines.Line2D at 0x259a1d7c4c0>,
#  <matplotlib.lines.Line2D at 0x259a1d7c5e0>,
#  <matplotlib.lines.Line2D at 0x259a1d7c700>,
#  <matplotlib.lines.Line2D at 0x259a1d7c820>,
#  <matplotlib.lines.Line2D at 0x259a1d7c940>,
#  <matplotlib.lines.Line2D at 0x259a1d7ca60>,
#  <matplotlib.lines.Line2D at 0x259a1d7cb80>,
#  <matplotlib.lines.Line2D at 0x259a1d7cca0>,
#  <matplotlib.lines.Line2D at 0x259a1d7cdc0>,
#  <matplotlib.lines.Line2D at 0x259a1d7cee0>,
#  <matplotlib.lines.Line2D at 0x259a1d81040>,
#  <matplotlib.lines.Line2D at 0x259a1d81160>,
#  <matplotlib.lines.Line2D at 0x259a1d81280>,
#  <matplotlib.lines.Line2D at 0x259a1d813a0>,
#  <matplotlib.lines.Line2D at 0x259a1d814c0>,
#  <matplotlib.lines.Line2D at 0x259a1d815e0>,
#  <matplotlib.lines.Line2D at 0x259a1d81700>,
#  <matplotlib.lines.Line2D at 0x259a1d81820>,
#  <matplotlib.lines.Line2D at 0x259a1d81940>,
#  <matplotlib.lines.Line2D at 0x259a1d81a60>,
#  <matplotlib.lines.Line2D at 0x259a1d81b80>,
#  <matplotlib.lines.Line2D at 0x259a1d81ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d81dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d81ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d89040>,
#  <matplotlib.lines.Line2D at 0x259a1d89160>,
#  <matplotlib.lines.Line2D at 0x259a1d89280>,
#  <matplotlib.lines.Line2D at 0x259a1d893a0>,
#  <matplotlib.lines.Line2D at 0x259a1d894c0>,
#  <matplotlib.lines.Line2D at 0x259a1d895e0>,
#  <matplotlib.lines.Line2D at 0x259a1d89700>,
#  <matplotlib.lines.Line2D at 0x259a1d89820>,
#  <matplotlib.lines.Line2D at 0x259a1d89940>,
#  <matplotlib.lines.Line2D at 0x259a1d89a60>,
#  <matplotlib.lines.Line2D at 0x259a1d89b80>,
#  <matplotlib.lines.Line2D at 0x259a1d89ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d89dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d89ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d8e040>,
#  <matplotlib.lines.Line2D at 0x259a1d8e160>,
#  <matplotlib.lines.Line2D at 0x259a1d8e280>,
#  <matplotlib.lines.Line2D at 0x259a1d8e3a0>,
#  <matplotlib.lines.Line2D at 0x259a1d8e4c0>,
#  <matplotlib.lines.Line2D at 0x259a1d8e5e0>,
#  <matplotlib.lines.Line2D at 0x259a1d8e700>,
#  <matplotlib.lines.Line2D at 0x259a1d8e820>,
#  <matplotlib.lines.Line2D at 0x259a1d8e940>,
#  <matplotlib.lines.Line2D at 0x259a1d8ea60>,
#  <matplotlib.lines.Line2D at 0x259a1d8eb80>,
#  <matplotlib.lines.Line2D at 0x259a1d8eca0>,
#  <matplotlib.lines.Line2D at 0x259a1d8edc0>,
#  <matplotlib.lines.Line2D at 0x259a1d8eee0>,
#  <matplotlib.lines.Line2D at 0x259a1d94040>,
#  <matplotlib.lines.Line2D at 0x259a1d94160>,
#  <matplotlib.lines.Line2D at 0x259a1d94280>,
#  <matplotlib.lines.Line2D at 0x259a1d943a0>,
#  <matplotlib.lines.Line2D at 0x259a1d944c0>,
#  <matplotlib.lines.Line2D at 0x259a1d945e0>,
#  <matplotlib.lines.Line2D at 0x259a1d94700>,
#  <matplotlib.lines.Line2D at 0x259a1d94820>,
#  <matplotlib.lines.Line2D at 0x259a1d94940>,
#  <matplotlib.lines.Line2D at 0x259a1d94a60>,
#  <matplotlib.lines.Line2D at 0x259a1d94b80>,
#  <matplotlib.lines.Line2D at 0x259a1d94ca0>,
#  <matplotlib.lines.Line2D at 0x259a1d94dc0>,
#  <matplotlib.lines.Line2D at 0x259a1d94ee0>,
#  <matplotlib.lines.Line2D at 0x259a1d9b040>,
#  <matplotlib.lines.Line2D at 0x259a1d9b160>,
#  <matplotlib.lines.Line2D at 0x259a1d9b280>,
#  <matplotlib.lines.Line2D at 0x259a1d9b3a0>,
#  <matplotlib.lines.Line2D at 0x259a1d9b4c0>,
#  <matplotlib.lines.Line2D at 0x259a1d9b5e0>,
#  <matplotlib.lines.Line2D at 0x259a1d9b700>,
#  <matplotlib.lines.Line2D at 0x259a1d9b820>,
#  <matplotlib.lines.Line2D at 0x259a1d9b940>,
#  <matplotlib.lines.Line2D at 0x259a1d9ba60>,
#  <matplotlib.lines.Line2D at 0x259a1d9bb80>,
#  <matplotlib.lines.Line2D at 0x259a1d9bca0>,
#  <matplotlib.lines.Line2D at 0x259a1d9bdc0>,
#  <matplotlib.lines.Line2D at 0x259a1d9bee0>,
#  <matplotlib.lines.Line2D at 0x259a1d9e040>,
#  <matplotlib.lines.Line2D at 0x259a1d9e160>,
#  <matplotlib.lines.Line2D at 0x259a1d9e280>,
#  <matplotlib.lines.Line2D at 0x259a1d9e3a0>,
#  <matplotlib.lines.Line2D at 0x259a1d9e4c0>,
#  <matplotlib.lines.Line2D at 0x259a1d9e5e0>,
#  <matplotlib.lines.Line2D at 0x259a1d9e700>,
#  <matplotlib.lines.Line2D at 0x259a1d9e820>,
#  <matplotlib.lines.Line2D at 0x259a1d9e940>,
#  <matplotlib.lines.Line2D at 0x259a1d9ea60>,
#  <matplotlib.lines.Line2D at 0x259a1d9eb80>,
#  <matplotlib.lines.Line2D at 0x259a1d9eca0>,
#  <matplotlib.lines.Line2D at 0x259a1d9edc0>,
#  <matplotlib.lines.Line2D at 0x259a1d9eee0>,
#  <matplotlib.lines.Line2D at 0x259a1da5040>,
#  <matplotlib.lines.Line2D at 0x259a1da5160>,
#  <matplotlib.lines.Line2D at 0x259a1da5280>,
#  <matplotlib.lines.Line2D at 0x259a1da53a0>,
#  <matplotlib.lines.Line2D at 0x259a1da54c0>,
#  <matplotlib.lines.Line2D at 0x259a1da55e0>,
#  <matplotlib.lines.Line2D at 0x259a1da5700>,
#  <matplotlib.lines.Line2D at 0x259a1da5820>,
#  <matplotlib.lines.Line2D at 0x259a1da5940>,
#  <matplotlib.lines.Line2D at 0x259a1da5a60>,
#  <matplotlib.lines.Line2D at 0x259a1da5b80>,
#  <matplotlib.lines.Line2D at 0x259a1da5ca0>,
#  <matplotlib.lines.Line2D at 0x259a1da5dc0>,
#  <matplotlib.lines.Line2D at 0x259a1da5ee0>,
#  <matplotlib.lines.Line2D at 0x259a1dac040>,
#  <matplotlib.lines.Line2D at 0x259a1dac160>,
#  <matplotlib.lines.Line2D at 0x259a1dac280>,
#  <matplotlib.lines.Line2D at 0x259a1dac3a0>,
#  <matplotlib.lines.Line2D at 0x259a1dac4c0>,
#  <matplotlib.lines.Line2D at 0x259a1dac5e0>,
#  <matplotlib.lines.Line2D at 0x259a1dac700>,
#  <matplotlib.lines.Line2D at 0x259a1dac820>,
#  <matplotlib.lines.Line2D at 0x259a1dac940>,
#  <matplotlib.lines.Line2D at 0x259a1daca60>,
#  <matplotlib.lines.Line2D at 0x259a1dacb80>,
#  <matplotlib.lines.Line2D at 0x259a1dacca0>,
#  <matplotlib.lines.Line2D at 0x259a1dacdc0>,
#  <matplotlib.lines.Line2D at 0x259a1dacee0>,
#  <matplotlib.lines.Line2D at 0x259a1db0040>,
#  <matplotlib.lines.Line2D at 0x259a1db0160>,
#  <matplotlib.lines.Line2D at 0x259a1db0280>,
#  <matplotlib.lines.Line2D at 0x259a1db03a0>,
#  <matplotlib.lines.Line2D at 0x259a1db04c0>,
#  <matplotlib.lines.Line2D at 0x259a1db05e0>,
#  <matplotlib.lines.Line2D at 0x259a1db0700>,
#  <matplotlib.lines.Line2D at 0x259a1db0820>,
#  <matplotlib.lines.Line2D at 0x259a1db0940>,
#  <matplotlib.lines.Line2D at 0x259a1db0a60>,
#  <matplotlib.lines.Line2D at 0x259a1db0b80>,
#  <matplotlib.lines.Line2D at 0x259a1db0ca0>,
#  <matplotlib.lines.Line2D at 0x259a1db0dc0>,
#  <matplotlib.lines.Line2D at 0x259a1db0ee0>,
#  <matplotlib.lines.Line2D at 0x259a1db6040>,
#  <matplotlib.lines.Line2D at 0x259a1db6160>,
#  <matplotlib.lines.Line2D at 0x259a1db6280>,
#  <matplotlib.lines.Line2D at 0x259a1db63a0>,
#  <matplotlib.lines.Line2D at 0x259a1db64c0>,
#  <matplotlib.lines.Line2D at 0x259a1db65e0>,
#  <matplotlib.lines.Line2D at 0x259a1db6700>,
#  <matplotlib.lines.Line2D at 0x259a1db6820>,
#  <matplotlib.lines.Line2D at 0x259a1db6940>,
#  <matplotlib.lines.Line2D at 0x259a1db6a60>,
#  <matplotlib.lines.Line2D at 0x259a1db6b80>,
#  <matplotlib.lines.Line2D at 0x259a1db6ca0>,
#  <matplotlib.lines.Line2D at 0x259a1db6dc0>,
#  <matplotlib.lines.Line2D at 0x259a1db6ee0>,
#  <matplotlib.lines.Line2D at 0x259a1dbd040>,
#  <matplotlib.lines.Line2D at 0x259a1dbd160>,
#  <matplotlib.lines.Line2D at 0x259a1dbd280>,
#  <matplotlib.lines.Line2D at 0x259a1dbd3a0>,
#  <matplotlib.lines.Line2D at 0x259a1dbd4c0>,
#  <matplotlib.lines.Line2D at 0x259a1dbd5e0>,
#  <matplotlib.lines.Line2D at 0x259a1dbd700>,
#  <matplotlib.lines.Line2D at 0x259a1dbd820>,
#  <matplotlib.lines.Line2D at 0x259a1dbd940>,
#  <matplotlib.lines.Line2D at 0x259a1dbda60>,
#  <matplotlib.lines.Line2D at 0x259a1dbdb80>,
#  <matplotlib.lines.Line2D at 0x259a1dbdca0>,
#  <matplotlib.lines.Line2D at 0x259a1dbddc0>,
#  <matplotlib.lines.Line2D at 0x259a1dbdee0>,
#  <matplotlib.lines.Line2D at 0x259a1dc2040>,
#  <matplotlib.lines.Line2D at 0x259a1dc2160>,
#  <matplotlib.lines.Line2D at 0x259a1dc2280>,
#  <matplotlib.lines.Line2D at 0x259a1dc23a0>,
#  <matplotlib.lines.Line2D at 0x259a1dc24c0>,
#  <matplotlib.lines.Line2D at 0x259a1dc25e0>,
#  <matplotlib.lines.Line2D at 0x259a1dc2700>,
#  <matplotlib.lines.Line2D at 0x259a1dc2820>,
#  <matplotlib.lines.Line2D at 0x259a1dc2940>,
#  <matplotlib.lines.Line2D at 0x259a1dc2a60>,
#  <matplotlib.lines.Line2D at 0x259a1dc2b80>,
#  <matplotlib.lines.Line2D at 0x259a1dc2ca0>,
#  <matplotlib.lines.Line2D at 0x259a1dc2dc0>,
#  <matplotlib.lines.Line2D at 0x259a1dc2ee0>,
#  <matplotlib.lines.Line2D at 0x259a1dc9040>,
#  <matplotlib.lines.Line2D at 0x259a1dc9160>,
#  <matplotlib.lines.Line2D at 0x259a1dc9280>,
#  <matplotlib.lines.Line2D at 0x259a1dc93a0>,
#  <matplotlib.lines.Line2D at 0x259a1dc94c0>,
#  <matplotlib.lines.Line2D at 0x259a1dc95e0>,
#  <matplotlib.lines.Line2D at 0x259a1dc9700>,
#  <matplotlib.lines.Line2D at 0x259a1dc9820>,
#  <matplotlib.lines.Line2D at 0x259a1dc9940>,
#  <matplotlib.lines.Line2D at 0x259a1dc9a60>,
#  <matplotlib.lines.Line2D at 0x259a1dc9b80>,
#  <matplotlib.lines.Line2D at 0x259a1dc9ca0>,
#  <matplotlib.lines.Line2D at 0x259a1dc9dc0>,
#  <matplotlib.lines.Line2D at 0x259a1dc9ee0>,
#  <matplotlib.lines.Line2D at 0x259a1dcf040>,
#  <matplotlib.lines.Line2D at 0x259a1dcf160>,
#  <matplotlib.lines.Line2D at 0x259a1dcf280>,
#  <matplotlib.lines.Line2D at 0x259a1dcf3a0>,
#  <matplotlib.lines.Line2D at 0x259a1dcf4c0>,
#  <matplotlib.lines.Line2D at 0x259a1dcf5e0>,
#  <matplotlib.lines.Line2D at 0x259a1dcf700>,
#  <matplotlib.lines.Line2D at 0x259a1dcf820>,
#  <matplotlib.lines.Line2D at 0x259a1dcf940>,
#  <matplotlib.lines.Line2D at 0x259a1dcfa60>,
#  <matplotlib.lines.Line2D at 0x259a1dcfb80>,
#  <matplotlib.lines.Line2D at 0x259a1dcfca0>,
#  <matplotlib.lines.Line2D at 0x259a1dcfdc0>,
#  <matplotlib.lines.Line2D at 0x259a1dcfee0>,
#  <matplotlib.lines.Line2D at 0x259a1dd3040>,
#  <matplotlib.lines.Line2D at 0x259a1dd3160>,
#  <matplotlib.lines.Line2D at 0x259a1dd3280>,
#  <matplotlib.lines.Line2D at 0x259a1dd33a0>,
#  <matplotlib.lines.Line2D at 0x259a1dd34c0>,
#  <matplotlib.lines.Line2D at 0x259a1dd35e0>,
#  <matplotlib.lines.Line2D at 0x259a1dd3700>,
#  <matplotlib.lines.Line2D at 0x259a1dd3820>,
#  <matplotlib.lines.Line2D at 0x259a1dd3940>,
#  <matplotlib.lines.Line2D at 0x259a1dd3a60>,
#  <matplotlib.lines.Line2D at 0x259a1dd3b80>,
#  <matplotlib.lines.Line2D at 0x259a1dd3ca0>,
#  <matplotlib.lines.Line2D at 0x259a1dd3dc0>,
#  <matplotlib.lines.Line2D at 0x259a1dd3ee0>,
#  <matplotlib.lines.Line2D at 0x259a1dda040>,
#  <matplotlib.lines.Line2D at 0x259a1dda160>,
#  <matplotlib.lines.Line2D at 0x259a1dda280>,
#  <matplotlib.lines.Line2D at 0x259a1dda3a0>,
#  <matplotlib.lines.Line2D at 0x259a1dda4c0>,
#  <matplotlib.lines.Line2D at 0x259a1dda5e0>,
#  <matplotlib.lines.Line2D at 0x259a1dda700>,
#  <matplotlib.lines.Line2D at 0x259a1dda820>,
#  <matplotlib.lines.Line2D at 0x259a1dda940>,
#  <matplotlib.lines.Line2D at 0x259a1ddaa60>,
#  <matplotlib.lines.Line2D at 0x259a1ddab80>,
#  <matplotlib.lines.Line2D at 0x259a1ddaca0>,
#  <matplotlib.lines.Line2D at 0x259a1ddadc0>,
#  <matplotlib.lines.Line2D at 0x259a1ddaee0>,
#  <matplotlib.lines.Line2D at 0x259a1de0040>,
#  <matplotlib.lines.Line2D at 0x259a1de0160>,
#  <matplotlib.lines.Line2D at 0x259a1de0280>,
#  <matplotlib.lines.Line2D at 0x259a1de03a0>,
#  <matplotlib.lines.Line2D at 0x259a1de04c0>,
#  <matplotlib.lines.Line2D at 0x259a1de05e0>,
#  <matplotlib.lines.Line2D at 0x259a1de0700>,
#  <matplotlib.lines.Line2D at 0x259a1de0820>,
#  <matplotlib.lines.Line2D at 0x259a1de0940>,
#  <matplotlib.lines.Line2D at 0x259a1de0a60>,
#  <matplotlib.lines.Line2D at 0x259a1de0b80>,
#  <matplotlib.lines.Line2D at 0x259a1de0ca0>,
#  <matplotlib.lines.Line2D at 0x259a1de0dc0>,
#  <matplotlib.lines.Line2D at 0x259a1de0ee0>,
#  <matplotlib.lines.Line2D at 0x259a1de5040>,
#  <matplotlib.lines.Line2D at 0x259a1de5160>,
#  <matplotlib.lines.Line2D at 0x259a1de5280>,
#  <matplotlib.lines.Line2D at 0x259a1de53a0>,
#  <matplotlib.lines.Line2D at 0x259a1de54c0>,
#  <matplotlib.lines.Line2D at 0x259a1de55e0>,
#  <matplotlib.lines.Line2D at 0x259a1de5700>,
#  <matplotlib.lines.Line2D at 0x259a1de5820>,
#  <matplotlib.lines.Line2D at 0x259a1de5940>,
#  <matplotlib.lines.Line2D at 0x259a1de5a60>,
#  <matplotlib.lines.Line2D at 0x259a1de5b80>,
#  <matplotlib.lines.Line2D at 0x259a1de5ca0>,
#  <matplotlib.lines.Line2D at 0x259a1de5dc0>,
#  <matplotlib.lines.Line2D at 0x259a1de5ee0>,
#  <matplotlib.lines.Line2D at 0x259a1deb040>,
#  <matplotlib.lines.Line2D at 0x259a1deb160>,
#  <matplotlib.lines.Line2D at 0x259a1deb280>,
#  <matplotlib.lines.Line2D at 0x259a1deb3a0>,
#  <matplotlib.lines.Line2D at 0x259a1deb4c0>,
#  <matplotlib.lines.Line2D at 0x259a1deb5e0>,
#  <matplotlib.lines.Line2D at 0x259a1deb700>,
#  <matplotlib.lines.Line2D at 0x259a1deb820>,
#  <matplotlib.lines.Line2D at 0x259a1deb940>,
#  <matplotlib.lines.Line2D at 0x259a1deba60>,
#  <matplotlib.lines.Line2D at 0x259a1debb80>,
#  <matplotlib.lines.Line2D at 0x259a1debca0>,
#  <matplotlib.lines.Line2D at 0x259a1debdc0>,
#  <matplotlib.lines.Line2D at 0x259a1debee0>,
#  <matplotlib.lines.Line2D at 0x259a1df2040>,
#  <matplotlib.lines.Line2D at 0x259a1df2160>,
#  <matplotlib.lines.Line2D at 0x259a1df2280>,
#  <matplotlib.lines.Line2D at 0x259a1df23a0>,
#  <matplotlib.lines.Line2D at 0x259a1df24c0>,
#  <matplotlib.lines.Line2D at 0x259a1df25e0>,
#  <matplotlib.lines.Line2D at 0x259a1df2700>,
#  <matplotlib.lines.Line2D at 0x259a1df2820>,
#  <matplotlib.lines.Line2D at 0x259a1df2940>,
#  <matplotlib.lines.Line2D at 0x259a1df2a60>,
#  <matplotlib.lines.Line2D at 0x259a1df2b80>,
#  <matplotlib.lines.Line2D at 0x259a1df2ca0>,
#  <matplotlib.lines.Line2D at 0x259a1df2dc0>,
#  <matplotlib.lines.Line2D at 0x259a1df2ee0>,
#  <matplotlib.lines.Line2D at 0x259a1df7040>,
#  <matplotlib.lines.Line2D at 0x259a1df7160>,
#  <matplotlib.lines.Line2D at 0x259a1df7280>,
#  <matplotlib.lines.Line2D at 0x259a1df73a0>,
#  <matplotlib.lines.Line2D at 0x259a1df74c0>,
#  <matplotlib.lines.Line2D at 0x259a1df75e0>,
#  <matplotlib.lines.Line2D at 0x259a1df7700>,
#  <matplotlib.lines.Line2D at 0x259a1df7820>,
#  <matplotlib.lines.Line2D at 0x259a1df7940>,
#  <matplotlib.lines.Line2D at 0x259a1df7a60>,
#  <matplotlib.lines.Line2D at 0x259a1df7b80>,
#  <matplotlib.lines.Line2D at 0x259a1df7ca0>,
#  <matplotlib.lines.Line2D at 0x259a1df7dc0>,
#  <matplotlib.lines.Line2D at 0x259a1df7ee0>,
#  <matplotlib.lines.Line2D at 0x259a1dfd040>,
#  <matplotlib.lines.Line2D at 0x259a1dfd160>,
#  <matplotlib.lines.Line2D at 0x259a1dfd280>,
#  <matplotlib.lines.Line2D at 0x259a1dfd3a0>,
#  <matplotlib.lines.Line2D at 0x259a1dfd4c0>,
#  <matplotlib.lines.Line2D at 0x259a1dfd5e0>,
#  <matplotlib.lines.Line2D at 0x259a1dfd700>,
#  <matplotlib.lines.Line2D at 0x259a1dfd820>,
#  <matplotlib.lines.Line2D at 0x259a1dfd940>,
#  <matplotlib.lines.Line2D at 0x259a1dfda60>,
#  <matplotlib.lines.Line2D at 0x259a1dfdb80>,
#  <matplotlib.lines.Line2D at 0x259a1dfdca0>,
#  <matplotlib.lines.Line2D at 0x259a1dfddc0>,
#  <matplotlib.lines.Line2D at 0x259a1dfdee0>,
#  <matplotlib.lines.Line2D at 0x259a1e04040>,
#  <matplotlib.lines.Line2D at 0x259a1e04160>,
#  <matplotlib.lines.Line2D at 0x259a1e04280>,
#  <matplotlib.lines.Line2D at 0x259a1e043a0>,
#  <matplotlib.lines.Line2D at 0x259a1e044c0>,
#  <matplotlib.lines.Line2D at 0x259a1e045e0>,
#  <matplotlib.lines.Line2D at 0x259a1e04700>,
#  <matplotlib.lines.Line2D at 0x259a1e04820>,
#  <matplotlib.lines.Line2D at 0x259a1e04940>,
#  <matplotlib.lines.Line2D at 0x259a1e04a60>,
#  <matplotlib.lines.Line2D at 0x259a1e04b80>,
#  <matplotlib.lines.Line2D at 0x259a1e04ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e04dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e04ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e07040>,
#  <matplotlib.lines.Line2D at 0x259a1e07160>,
#  <matplotlib.lines.Line2D at 0x259a1e07280>,
#  <matplotlib.lines.Line2D at 0x259a1e073a0>,
#  <matplotlib.lines.Line2D at 0x259a1e074c0>,
#  <matplotlib.lines.Line2D at 0x259a1e075e0>,
#  <matplotlib.lines.Line2D at 0x259a1e07700>,
#  <matplotlib.lines.Line2D at 0x259a1e07820>,
#  <matplotlib.lines.Line2D at 0x259a1e07940>,
#  <matplotlib.lines.Line2D at 0x259a1e07a60>,
#  <matplotlib.lines.Line2D at 0x259a1e07b80>,
#  <matplotlib.lines.Line2D at 0x259a1e07ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e07dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e07ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e0e040>,
#  <matplotlib.lines.Line2D at 0x259a1e0e160>,
#  <matplotlib.lines.Line2D at 0x259a1e0e280>,
#  <matplotlib.lines.Line2D at 0x259a1e0e3a0>,
#  <matplotlib.lines.Line2D at 0x259a1e0e4c0>,
#  <matplotlib.lines.Line2D at 0x259a1e0e5e0>,
#  <matplotlib.lines.Line2D at 0x259a1e0e700>,
#  <matplotlib.lines.Line2D at 0x259a1e0e820>,
#  <matplotlib.lines.Line2D at 0x259a1e0e940>,
#  <matplotlib.lines.Line2D at 0x259a1e0ea60>,
#  <matplotlib.lines.Line2D at 0x259a1e0eb80>,
#  <matplotlib.lines.Line2D at 0x259a1e0eca0>,
#  <matplotlib.lines.Line2D at 0x259a1e0edc0>,
#  <matplotlib.lines.Line2D at 0x259a1e0eee0>,
#  <matplotlib.lines.Line2D at 0x259a1e15040>,
#  <matplotlib.lines.Line2D at 0x259a1e15160>,
#  <matplotlib.lines.Line2D at 0x259a1e15280>,
#  <matplotlib.lines.Line2D at 0x259a1e153a0>,
#  <matplotlib.lines.Line2D at 0x259a1e154c0>,
#  <matplotlib.lines.Line2D at 0x259a1e155e0>,
#  <matplotlib.lines.Line2D at 0x259a1e15700>,
#  <matplotlib.lines.Line2D at 0x259a1e15820>,
#  <matplotlib.lines.Line2D at 0x259a1e15940>,
#  <matplotlib.lines.Line2D at 0x259a1e15a60>,
#  <matplotlib.lines.Line2D at 0x259a1e15b80>,
#  <matplotlib.lines.Line2D at 0x259a1e15ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e15dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e15ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e19040>,
#  <matplotlib.lines.Line2D at 0x259a1e19160>,
#  <matplotlib.lines.Line2D at 0x259a1e19280>,
#  <matplotlib.lines.Line2D at 0x259a1e193a0>,
#  <matplotlib.lines.Line2D at 0x259a1e194c0>,
#  <matplotlib.lines.Line2D at 0x259a1e195e0>,
#  <matplotlib.lines.Line2D at 0x259a1e19700>,
#  <matplotlib.lines.Line2D at 0x259a1e19820>,
#  <matplotlib.lines.Line2D at 0x259a1e19940>,
#  <matplotlib.lines.Line2D at 0x259a1e19a60>,
#  <matplotlib.lines.Line2D at 0x259a1e19b80>,
#  <matplotlib.lines.Line2D at 0x259a1e19ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e19dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e19ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e20040>,
#  <matplotlib.lines.Line2D at 0x259a1e20160>,
#  <matplotlib.lines.Line2D at 0x259a1e20280>,
#  <matplotlib.lines.Line2D at 0x259a1e203a0>,
#  <matplotlib.lines.Line2D at 0x259a1e204c0>,
#  <matplotlib.lines.Line2D at 0x259a1e205e0>,
#  <matplotlib.lines.Line2D at 0x259a1e20700>,
#  <matplotlib.lines.Line2D at 0x259a1e20820>,
#  <matplotlib.lines.Line2D at 0x259a1e20940>,
#  <matplotlib.lines.Line2D at 0x259a1e20a60>,
#  <matplotlib.lines.Line2D at 0x259a1e20b80>,
#  <matplotlib.lines.Line2D at 0x259a1e20ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e20dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e20ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e26040>,
#  <matplotlib.lines.Line2D at 0x259a1e26160>,
#  <matplotlib.lines.Line2D at 0x259a1e26280>,
#  <matplotlib.lines.Line2D at 0x259a1e263a0>,
#  <matplotlib.lines.Line2D at 0x259a1e264c0>,
#  <matplotlib.lines.Line2D at 0x259a1e265e0>,
#  <matplotlib.lines.Line2D at 0x259a1e26700>,
#  <matplotlib.lines.Line2D at 0x259a1e26820>,
#  <matplotlib.lines.Line2D at 0x259a1e26940>,
#  <matplotlib.lines.Line2D at 0x259a1e26a60>,
#  <matplotlib.lines.Line2D at 0x259a1e26b80>,
#  <matplotlib.lines.Line2D at 0x259a1e26ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e26dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e26ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e2b040>,
#  <matplotlib.lines.Line2D at 0x259a1e2b160>,
#  <matplotlib.lines.Line2D at 0x259a1e2b280>,
#  <matplotlib.lines.Line2D at 0x259a1e2b3a0>,
#  <matplotlib.lines.Line2D at 0x259a1e2b4c0>,
#  <matplotlib.lines.Line2D at 0x259a1e2b5e0>,
#  <matplotlib.lines.Line2D at 0x259a1e2b700>,
#  <matplotlib.lines.Line2D at 0x259a1e2b820>,
#  <matplotlib.lines.Line2D at 0x259a1e2b940>,
#  <matplotlib.lines.Line2D at 0x259a1e2ba60>,
#  <matplotlib.lines.Line2D at 0x259a1e2bb80>,
#  <matplotlib.lines.Line2D at 0x259a1e2bca0>,
#  <matplotlib.lines.Line2D at 0x259a1e2bdc0>,
#  <matplotlib.lines.Line2D at 0x259a1e2bee0>,
#  <matplotlib.lines.Line2D at 0x259a1e32040>,
#  <matplotlib.lines.Line2D at 0x259a1e32160>,
#  <matplotlib.lines.Line2D at 0x259a1e32280>,
#  <matplotlib.lines.Line2D at 0x259a1e323a0>,
#  <matplotlib.lines.Line2D at 0x259a1e324c0>,
#  <matplotlib.lines.Line2D at 0x259a1e325e0>,
#  <matplotlib.lines.Line2D at 0x259a1e32700>,
#  <matplotlib.lines.Line2D at 0x259a1e32820>,
#  <matplotlib.lines.Line2D at 0x259a1e32940>,
#  <matplotlib.lines.Line2D at 0x259a1e32a60>,
#  <matplotlib.lines.Line2D at 0x259a1e32b80>,
#  <matplotlib.lines.Line2D at 0x259a1e32ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e32dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e32ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e38040>,
#  <matplotlib.lines.Line2D at 0x259a1e38160>,
#  <matplotlib.lines.Line2D at 0x259a1e38280>,
#  <matplotlib.lines.Line2D at 0x259a1e383a0>,
#  <matplotlib.lines.Line2D at 0x259a1e384c0>,
#  <matplotlib.lines.Line2D at 0x259a1e385e0>,
#  <matplotlib.lines.Line2D at 0x259a1e38700>,
#  <matplotlib.lines.Line2D at 0x259a1e38820>,
#  <matplotlib.lines.Line2D at 0x259a1e38940>,
#  <matplotlib.lines.Line2D at 0x259a1e38a60>,
#  <matplotlib.lines.Line2D at 0x259a1e38b80>,
#  <matplotlib.lines.Line2D at 0x259a1e38ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e38dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e38ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e3c040>,
#  <matplotlib.lines.Line2D at 0x259a1e3c160>,
#  <matplotlib.lines.Line2D at 0x259a1e3c280>,
#  <matplotlib.lines.Line2D at 0x259a1e3c3a0>,
#  <matplotlib.lines.Line2D at 0x259a1e3c4c0>,
#  <matplotlib.lines.Line2D at 0x259a1e3c5e0>,
#  <matplotlib.lines.Line2D at 0x259a1e3c700>,
#  <matplotlib.lines.Line2D at 0x259a1e3c820>,
#  <matplotlib.lines.Line2D at 0x259a1e3c940>,
#  <matplotlib.lines.Line2D at 0x259a1e3ca60>,
#  <matplotlib.lines.Line2D at 0x259a1e3cb80>,
#  <matplotlib.lines.Line2D at 0x259a1e3cca0>,
#  <matplotlib.lines.Line2D at 0x259a1e3cdc0>,
#  <matplotlib.lines.Line2D at 0x259a1e3cee0>,
#  <matplotlib.lines.Line2D at 0x259a1e42040>,
#  <matplotlib.lines.Line2D at 0x259a1e42160>,
#  <matplotlib.lines.Line2D at 0x259a1e42280>,
#  <matplotlib.lines.Line2D at 0x259a1e423a0>,
#  <matplotlib.lines.Line2D at 0x259a1e424c0>,
#  <matplotlib.lines.Line2D at 0x259a1e425e0>,
#  <matplotlib.lines.Line2D at 0x259a1e42700>,
#  <matplotlib.lines.Line2D at 0x259a1e42820>,
#  <matplotlib.lines.Line2D at 0x259a1e42940>,
#  <matplotlib.lines.Line2D at 0x259a1e42a60>,
#  <matplotlib.lines.Line2D at 0x259a1e42b80>,
#  <matplotlib.lines.Line2D at 0x259a1e42ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e42dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e42ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e49040>,
#  <matplotlib.lines.Line2D at 0x259a1e49160>,
#  <matplotlib.lines.Line2D at 0x259a1e49280>,
#  <matplotlib.lines.Line2D at 0x259a1e493a0>,
#  <matplotlib.lines.Line2D at 0x259a1e494c0>,
#  <matplotlib.lines.Line2D at 0x259a1e495e0>,
#  <matplotlib.lines.Line2D at 0x259a1e49700>,
#  <matplotlib.lines.Line2D at 0x259a1e49820>,
#  <matplotlib.lines.Line2D at 0x259a1e49940>,
#  <matplotlib.lines.Line2D at 0x259a1e49a60>,
#  <matplotlib.lines.Line2D at 0x259a1e49b80>,
#  <matplotlib.lines.Line2D at 0x259a1e49ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e49dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e49ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e4f040>,
#  <matplotlib.lines.Line2D at 0x259a1e4f160>,
#  <matplotlib.lines.Line2D at 0x259a1e4f280>,
#  <matplotlib.lines.Line2D at 0x259a1e4f3a0>,
#  <matplotlib.lines.Line2D at 0x259a1e4f4c0>,
#  <matplotlib.lines.Line2D at 0x259a1e4f5e0>,
#  <matplotlib.lines.Line2D at 0x259a1e4f700>,
#  <matplotlib.lines.Line2D at 0x259a1e4f820>,
#  <matplotlib.lines.Line2D at 0x259a1e4f940>,
#  <matplotlib.lines.Line2D at 0x259a1e4fa60>,
#  <matplotlib.lines.Line2D at 0x259a1e4fb80>,
#  <matplotlib.lines.Line2D at 0x259a1e4fca0>,
#  <matplotlib.lines.Line2D at 0x259a1e4fdc0>,
#  <matplotlib.lines.Line2D at 0x259a1e4fee0>,
#  <matplotlib.lines.Line2D at 0x259a1e54040>,
#  <matplotlib.lines.Line2D at 0x259a1e54160>,
#  <matplotlib.lines.Line2D at 0x259a1e54280>,
#  <matplotlib.lines.Line2D at 0x259a1e543a0>,
#  <matplotlib.lines.Line2D at 0x259a1e544c0>,
#  <matplotlib.lines.Line2D at 0x259a1e545e0>,
#  <matplotlib.lines.Line2D at 0x259a1e54700>,
#  <matplotlib.lines.Line2D at 0x259a1e54820>,
#  <matplotlib.lines.Line2D at 0x259a1e54940>,
#  <matplotlib.lines.Line2D at 0x259a1e54a60>,
#  <matplotlib.lines.Line2D at 0x259a1e54b80>,
#  <matplotlib.lines.Line2D at 0x259a1e54ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e54dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e54ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e5b040>,
#  <matplotlib.lines.Line2D at 0x259a1e5b160>,
#  <matplotlib.lines.Line2D at 0x259a1e5b280>,
#  <matplotlib.lines.Line2D at 0x259a1e5b3a0>,
#  <matplotlib.lines.Line2D at 0x259a1e5b4c0>,
#  <matplotlib.lines.Line2D at 0x259a1e5b5e0>,
#  <matplotlib.lines.Line2D at 0x259a1e5b700>,
#  <matplotlib.lines.Line2D at 0x259a1e5b820>,
#  <matplotlib.lines.Line2D at 0x259a1e5b940>,
#  <matplotlib.lines.Line2D at 0x259a1e5ba60>,
#  <matplotlib.lines.Line2D at 0x259a1e5bb80>,
#  <matplotlib.lines.Line2D at 0x259a1e5bca0>,
#  <matplotlib.lines.Line2D at 0x259a1e5bdc0>,
#  <matplotlib.lines.Line2D at 0x259a1e5bee0>,
#  <matplotlib.lines.Line2D at 0x259a1e60040>,
#  <matplotlib.lines.Line2D at 0x259a1e60160>,
#  <matplotlib.lines.Line2D at 0x259a1e60280>,
#  <matplotlib.lines.Line2D at 0x259a1e603a0>,
#  <matplotlib.lines.Line2D at 0x259a1e604c0>,
#  <matplotlib.lines.Line2D at 0x259a1e605e0>,
#  <matplotlib.lines.Line2D at 0x259a1e60700>,
#  <matplotlib.lines.Line2D at 0x259a1e60820>,
#  <matplotlib.lines.Line2D at 0x259a1e60940>,
#  <matplotlib.lines.Line2D at 0x259a1e60a60>,
#  <matplotlib.lines.Line2D at 0x259a1e60b80>,
#  <matplotlib.lines.Line2D at 0x259a1e60ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e60dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e60ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e66040>,
#  <matplotlib.lines.Line2D at 0x259a1e66160>,
#  <matplotlib.lines.Line2D at 0x259a1e66280>,
#  <matplotlib.lines.Line2D at 0x259a1e663a0>,
#  <matplotlib.lines.Line2D at 0x259a1e664c0>,
#  <matplotlib.lines.Line2D at 0x259a1e665e0>,
#  <matplotlib.lines.Line2D at 0x259a1e66700>,
#  <matplotlib.lines.Line2D at 0x259a1e66820>,
#  <matplotlib.lines.Line2D at 0x259a1e66940>,
#  <matplotlib.lines.Line2D at 0x259a1e66a60>,
#  <matplotlib.lines.Line2D at 0x259a1e66b80>,
#  <matplotlib.lines.Line2D at 0x259a1e66ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e66dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e66ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e6d040>,
#  <matplotlib.lines.Line2D at 0x259a1e6d160>,
#  <matplotlib.lines.Line2D at 0x259a1e6d280>,
#  <matplotlib.lines.Line2D at 0x259a1e6d3a0>,
#  <matplotlib.lines.Line2D at 0x259a1e6d4c0>,
#  <matplotlib.lines.Line2D at 0x259a1e6d5e0>,
#  <matplotlib.lines.Line2D at 0x259a1e6d700>,
#  <matplotlib.lines.Line2D at 0x259a1e6d820>,
#  <matplotlib.lines.Line2D at 0x259a1e6d940>,
#  <matplotlib.lines.Line2D at 0x259a1e6da60>,
#  <matplotlib.lines.Line2D at 0x259a1e6db80>,
#  <matplotlib.lines.Line2D at 0x259a1e6dca0>,
#  <matplotlib.lines.Line2D at 0x259a1e6ddc0>,
#  <matplotlib.lines.Line2D at 0x259a1e6dee0>,
#  <matplotlib.lines.Line2D at 0x259a1e70040>,
#  <matplotlib.lines.Line2D at 0x259a1e70160>,
#  <matplotlib.lines.Line2D at 0x259a1e70280>,
#  <matplotlib.lines.Line2D at 0x259a1e703a0>,
#  <matplotlib.lines.Line2D at 0x259a1e704c0>,
#  <matplotlib.lines.Line2D at 0x259a1e705e0>,
#  <matplotlib.lines.Line2D at 0x259a1e70700>,
#  <matplotlib.lines.Line2D at 0x259a1e70820>,
#  <matplotlib.lines.Line2D at 0x259a1e70940>,
#  <matplotlib.lines.Line2D at 0x259a1e70a60>,
#  <matplotlib.lines.Line2D at 0x259a1e70b80>,
#  <matplotlib.lines.Line2D at 0x259a1e70ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e70dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e70ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e77040>,
#  <matplotlib.lines.Line2D at 0x259a1e77160>,
#  <matplotlib.lines.Line2D at 0x259a1e77280>,
#  <matplotlib.lines.Line2D at 0x259a1e773a0>,
#  <matplotlib.lines.Line2D at 0x259a1e774c0>,
#  <matplotlib.lines.Line2D at 0x259a1e775e0>,
#  <matplotlib.lines.Line2D at 0x259a1e77700>,
#  <matplotlib.lines.Line2D at 0x259a1e77820>,
#  <matplotlib.lines.Line2D at 0x259a1e77940>,
#  <matplotlib.lines.Line2D at 0x259a1e77a60>,
#  <matplotlib.lines.Line2D at 0x259a1e77b80>,
#  <matplotlib.lines.Line2D at 0x259a1e77ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e77dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e77ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e7e040>,
#  <matplotlib.lines.Line2D at 0x259a1e7e160>,
#  <matplotlib.lines.Line2D at 0x259a1e7e280>,
#  <matplotlib.lines.Line2D at 0x259a1e7e3a0>,
#  <matplotlib.lines.Line2D at 0x259a1e7e4c0>,
#  <matplotlib.lines.Line2D at 0x259a1e7e5e0>,
#  <matplotlib.lines.Line2D at 0x259a1e7e700>,
#  <matplotlib.lines.Line2D at 0x259a1e7e820>,
#  <matplotlib.lines.Line2D at 0x259a1e7e940>,
#  <matplotlib.lines.Line2D at 0x259a1e7ea60>,
#  <matplotlib.lines.Line2D at 0x259a1e7eb80>,
#  <matplotlib.lines.Line2D at 0x259a1e7eca0>,
#  <matplotlib.lines.Line2D at 0x259a1e7edc0>,
#  <matplotlib.lines.Line2D at 0x259a1e7eee0>,
#  <matplotlib.lines.Line2D at 0x259a1e83040>,
#  <matplotlib.lines.Line2D at 0x259a1e83160>,
#  <matplotlib.lines.Line2D at 0x259a1e83280>,
#  <matplotlib.lines.Line2D at 0x259a1e833a0>,
#  <matplotlib.lines.Line2D at 0x259a1e834c0>,
#  <matplotlib.lines.Line2D at 0x259a1e835e0>,
#  <matplotlib.lines.Line2D at 0x259a1e83700>,
#  <matplotlib.lines.Line2D at 0x259a1e83820>,
#  <matplotlib.lines.Line2D at 0x259a1e83940>,
#  <matplotlib.lines.Line2D at 0x259a1e83a60>,
#  <matplotlib.lines.Line2D at 0x259a1e83b80>,
#  <matplotlib.lines.Line2D at 0x259a1e83ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e83dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e83ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e89040>,
#  <matplotlib.lines.Line2D at 0x259a1e89160>,
#  <matplotlib.lines.Line2D at 0x259a1e89280>,
#  <matplotlib.lines.Line2D at 0x259a1e893a0>,
#  <matplotlib.lines.Line2D at 0x259a1e894c0>,
#  <matplotlib.lines.Line2D at 0x259a1e895e0>,
#  <matplotlib.lines.Line2D at 0x259a1e89700>,
#  <matplotlib.lines.Line2D at 0x259a1e89820>,
#  <matplotlib.lines.Line2D at 0x259a1e89940>,
#  <matplotlib.lines.Line2D at 0x259a1e89a60>,
#  <matplotlib.lines.Line2D at 0x259a1e89b80>,
#  <matplotlib.lines.Line2D at 0x259a1e89ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e89dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e89ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e8f040>,
#  <matplotlib.lines.Line2D at 0x259a1e8f160>,
#  <matplotlib.lines.Line2D at 0x259a1e8f280>,
#  <matplotlib.lines.Line2D at 0x259a1e8f3a0>,
#  <matplotlib.lines.Line2D at 0x259a1e8f4c0>,
#  <matplotlib.lines.Line2D at 0x259a1e8f5e0>,
#  <matplotlib.lines.Line2D at 0x259a1e8f700>,
#  <matplotlib.lines.Line2D at 0x259a1e8f820>,
#  <matplotlib.lines.Line2D at 0x259a1e8f940>,
#  <matplotlib.lines.Line2D at 0x259a1e8fa60>,
#  <matplotlib.lines.Line2D at 0x259a1e8fb80>,
#  <matplotlib.lines.Line2D at 0x259a1e8fca0>,
#  <matplotlib.lines.Line2D at 0x259a1e8fdc0>,
#  <matplotlib.lines.Line2D at 0x259a1e8fee0>,
#  <matplotlib.lines.Line2D at 0x259a1e94040>,
#  <matplotlib.lines.Line2D at 0x259a1e94160>,
#  <matplotlib.lines.Line2D at 0x259a1e94280>,
#  <matplotlib.lines.Line2D at 0x259a1e943a0>,
#  <matplotlib.lines.Line2D at 0x259a1e944c0>,
#  <matplotlib.lines.Line2D at 0x259a1e945e0>,
#  <matplotlib.lines.Line2D at 0x259a1e94700>,
#  <matplotlib.lines.Line2D at 0x259a1e94820>,
#  <matplotlib.lines.Line2D at 0x259a1e94940>,
#  <matplotlib.lines.Line2D at 0x259a1e94a60>,
#  <matplotlib.lines.Line2D at 0x259a1e94b80>,
#  <matplotlib.lines.Line2D at 0x259a1e94ca0>,
#  <matplotlib.lines.Line2D at 0x259a1e94dc0>,
#  <matplotlib.lines.Line2D at 0x259a1e94ee0>,
#  <matplotlib.lines.Line2D at 0x259a1e9b040>,
#  <matplotlib.lines.Line2D at 0x259a1e9b160>,
#  <matplotlib.lines.Line2D at 0x259a1e9b280>,
#  <matplotlib.lines.Line2D at 0x259a1e9b3a0>,
#  <matplotlib.lines.Line2D at 0x259a1e9b4c0>,
#  <matplotlib.lines.Line2D at 0x259a1e9b5e0>,
#  <matplotlib.lines.Line2D at 0x259a1e9b700>,
#  <matplotlib.lines.Line2D at 0x259a1e9b820>,
#  <matplotlib.lines.Line2D at 0x259a1e9b940>,
#  <matplotlib.lines.Line2D at 0x259a1e9ba60>,
#  <matplotlib.lines.Line2D at 0x259a1e9bb80>,
#  <matplotlib.lines.Line2D at 0x259a1e9bca0>,
#  <matplotlib.lines.Line2D at 0x259a1e9bdc0>,
#  <matplotlib.lines.Line2D at 0x259a1e9bee0>,
#  <matplotlib.lines.Line2D at 0x259a1ea1040>,
#  <matplotlib.lines.Line2D at 0x259a1ea1160>,
#  <matplotlib.lines.Line2D at 0x259a1ea1280>,
#  <matplotlib.lines.Line2D at 0x259a1ea13a0>,
#  <matplotlib.lines.Line2D at 0x259a1ea14c0>,
#  <matplotlib.lines.Line2D at 0x259a1ea15e0>,
#  <matplotlib.lines.Line2D at 0x259a1ea1700>,
#  <matplotlib.lines.Line2D at 0x259a1ea1820>,
#  <matplotlib.lines.Line2D at 0x259a1ea1940>,
#  <matplotlib.lines.Line2D at 0x259a1ea1a60>,
#  <matplotlib.lines.Line2D at 0x259a1ea1b80>,
#  <matplotlib.lines.Line2D at 0x259a1ea1ca0>,
#  <matplotlib.lines.Line2D at 0x259a1ea1dc0>,
#  <matplotlib.lines.Line2D at 0x259a1ea1ee0>,
#  <matplotlib.lines.Line2D at 0x259a1ea5040>,
#  ...]

# %% [markdown]
# ## Figures

# %%
#chat gpt's solution - don't know whether it is useful

import numpy as np
import matplotlib.pyplot as plt

# Parameters
L = 1000.0  # Length of the domain
T = 1.0   # Final time
Nx = 100   # Number of spatial grid points
Nt = 100   # Number of time steps

# Spatial and temporal discretization
dx = L / (Nx - 1)
dt = T / Nt

# Constants
H = 0.5     # Characteristic vertical scale
beta_L = 1.0
S = 1.0
U = 1.5     # Characteristic horizontal velocity scale
k_S = 2.0
Q0 = 1.0

# Initial condition
def initial_condition(x):
    return np.sin(np.pi * x / L)

# Initialize grid
x_values = np.linspace(0, L, Nx)
phi_L = initial_condition(x_values)

# Time-stepping loop
for n in range(1, Nt + 1):
    # Compute the right-hand side
    RHS = -((k_S + 1 / H) * Q0 / U) * np.exp(-k_S * x_values)

    # Update phi_L using finite difference scheme
    phi_L[1:-1] = phi_L[1:-1] + dt * (
        (phi_L[2:] - 2 * phi_L[1:-1] + phi_L[:-2]) / dx**2
        - (1 / H) * (phi_L[2:] - phi_L[:-2]) / (2 * dx)
        + (beta_L * S / U) * phi_L[1:-1]
        + RHS[1:-1]
    )

# Plot the result
plt.plot(x_values, phi_L, label='Numerical Solution')
plt.title('Numerical Solution of the PDE')
plt.xlabel('x')
plt.ylabel('$\phi_L$')
plt.legend()
plt.show()

# %%
#chatgpt part 2

import numpy as np
import matplotlib.pyplot as plt

# Parameters
H = 0.5  # Example value for H, you should adjust according to your problem
beta_L = 1.0  # Example value for beta_L
k_S = 2.0  # Example value for k_S
Q0 = 1.0  # Example value for Q0
U = 1.5  # Example value for U

# Spatial parameters
L = 1000.0  # Total length
Nx = 1000  # Number of spatial grid points
dx = L / (Nx - 1)  # Spatial step size
x_values = np.linspace(0, L, Nx)

# Time parameters
T = 1.0  # Total time
Nt = 100  # Number of time steps
dt = T / (Nt - 1)  # Time step size

# Initial conditions
phi_L = (Q0 / U) * (np.sin(2 * x_values) / 2)

# Forward Euler method
for n in range(1, Nt):
    phi_L_new = np.zeros_like(phi_L)

    for i in range(1, Nx - 1):
        dz = (dt ** 2) / (1 + (dt / H))
        source_term = (k_S + 1 / H) * (Q0 / U) * np.exp(-k_S * x_values[i])

        phi_L_new[i] = dz * (
            source_term
            - (1 / H) * (phi_L[i] - phi_L[i - 1]) / dx
            + (beta_L * S / U) * phi_L[i]
            + 2 * phi_L[i]
            - phi_L[i - 1]
        )

    phi_L = phi_L_new

# Plot the result
plt.plot(x_values, phi_L)
plt.title("Solution of the PDE using Forward Euler")
plt.xlabel("z")
plt.ylabel("$\phi_L$")
plt.show()

# %%
#chatgpt pt 3

import numpy as np
import matplotlib.pyplot as plt

# Parameters
H = 1.0  # Example value for H, you should adjust according to your problem
beta_L = 1.0  # Example value for beta_L
k_S = 1.0  # Example value for k_S
Q0 = 1.0  # Example value for Q0
U = 1.0  # Example value for U
S = 1.0  # Example value for S

# Spatial parameters
L = 10.0  # Total length
Nx = 100  # Number of spatial grid points
dx = L / (Nx - 1)  # Spatial step size
x_values = np.linspace(0, L, Nx)

# Initial conditions
phi_L = (Q0 / U) * (np.sin(2 * x_values) / 2)

# Forward Euler method (spatial only)
for i in range(1, Nx - 1):
    dz = dx ** 2  # Adjust the step size as needed
    source_term = (k_S + 1 / H) * (Q0 / U) * np.exp(-k_S * x_values[i])

    phi_L[i] = dz * (
        source_term
        - (1 / H) * (phi_L[i] - phi_L[i - 1]) / dx
        + (beta_L * S / U) * phi_L[i]
        + 2 * phi_L[i]
        - phi_L[i - 1]
    )

# Plot the result
plt.plot(x_values, phi_L)
plt.title("Solution of the PDE in the Spatial Direction using Forward Euler")
plt.xlabel("z")
plt.ylabel("$\phi_L$")
plt.show()

# %%
#chatgpt pt 4

import numpy as np
import matplotlib.pyplot as plt

# Parameters
H = 1.0  # Example value for H, you should adjust according to your problem
beta_L = 1.0  # Example value for beta_L
k_S = 1.0  # Example value for k_S
Q0 = 1.0  # Example value for Q0
U = 1.0  # Example value for U
S = 1.0  # Example value for S

# Spatial parameters
L = 10.0  # Total length
Nx = 100  # Number of spatial grid points
dx = L / (Nx - 1)  # Spatial step size
x_values = np.linspace(0, L, Nx)

# Time parameters
T = 1.0  # Total time
Nt = 100  # Number of time steps
dt = T / (Nt - 1)  # Time step size

# Advection and diffusion coefficients
u = -1 / H
D = (beta_L * S) / U

# Initial conditions
phi_L = (Q0 / U) * (np.sin(2 * x_values) / 2)

# Finite Difference Method
for n in range(1, Nt):
    phi_L_new = np.zeros_like(phi_L)

    for i in range(1, Nx - 1):
        # Advection term
        adv = u * (phi_L[i + 1] - phi_L[i - 1]) / (2 * dx)

        # Diffusion term
        diff = D * (phi_L[i + 1] - 2 * phi_L[i] + phi_L[i - 1]) / (dx**2)

        # Source term
        source_term = S

        # Update using finite difference method
        phi_L_new[i] = phi_L[i] + dt * (adv + diff + source_term)

    phi_L = phi_L_new

# Plot the result
plt.plot(x_values, phi_L)
plt.title("Solution of Advection-Diffusion Equation using Finite Difference Method")
plt.xlabel("z")
plt.ylabel("$\phi_L$")
plt.show()

# %%
#chatgpt 5

import numpy as np
import matplotlib.pyplot as plt

# Parameters
H = 1.0  # Example value for H, you should adjust according to your problem
beta_L = 1.0  # Example value for beta_L
k_S = 1.0  # Example value for k_S
Q0 = 1.0  # Example value for Q0
U = 1.0  # Example value for U
S = 1.0  # Example value for S

# Spatial parameters
L = 10.0  # Total length
Nx = 100  # Number of spatial grid points
dx = L / (Nx - 1)  # Spatial step size
x_values = np.linspace(0, L, Nx)

# Advection and diffusion coefficients
u = -1 / H
D = (beta_L * S) / U

# Initial conditions
phi_L = (Q0 / U) * (np.sin(2 * x_values) / 2)

# Finite Difference Method (spatial only)
for i in range(1, Nx - 1):
    # Advection term
    adv = u * (phi_L[i + 1] - phi_L[i - 1]) / (2 * dx)

    # Diffusion term
    diff = D * (phi_L[i + 1] - 2 * phi_L[i] + phi_L[i - 1]) / (dx**2)

    # Source term
    source_term = - (k_S + 1 / H) * (Q0 / U) * np.exp(-k_S * x_values[i]) * (np.sin(2 * x_values[i]) / 2)

    # Update using finite difference method
    phi_L[i] = phi_L[i] + dx * (adv + diff + source_term)

# Plot the result
plt.plot(x_values, phi_L)
plt.title("Solution of Spatial Advection-Diffusion Equation using Finite Difference Method")
plt.xlabel("z")
plt.ylabel("$\phi_L$")
plt.show()
